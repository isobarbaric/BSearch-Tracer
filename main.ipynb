# %% [markdown]
# binary search visualizer

# %%
a = [1, 3, 10, 53, 233, 1214]

# %%
# returns index of element using binary search
def binary_search(nums: list, target: int, low: int, high: int):
    if low > high:
        return -1

    mid = (low + high) // 2

    if nums[mid] == target:
        return mid
    elif nums[mid] < target:
        return binary_search(nums, target, mid+1, high)
    else:
        return binary_search(nums, target, low, mid-1)

# %%
def find_element(nums: list, target: int):
    return binary_search(nums, target, 0, len(nums)-1)

# %%
find_element(a, 53)
# Out:
# 3

# %% [markdown]
# get path for binary search pointer
